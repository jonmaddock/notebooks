# %% [markdown]
# # Plot constraints

# %%
# Reload Process each time (keep editable install up-to-date)
# %load_ext autoreload
# %autoreload 2
from process.main import SingleRun
from process.io.plot_solutions import RunMetadata, plot_mfile_solutions, plot_mfile_solutions_constraints

# %%
runs_metadata = [
    RunMetadata("large_tokamak_ineqs_MFILE.DAT", "DEMO solution"),
    # RunMetadata("large_tokamak_nof_mod_cons_MFILE.DAT", "Modified cons"),
]

fig, once_through_df = plot_mfile_solutions_constraints(
    runs_metadata=runs_metadata,
    title="Constraint values at large tokamak solution",
)

# %%
once_through_df
# Out:
#              tag     eq_con001     eq_con002  eq_con011  ineq_con005  \
# 0  DEMO solution  4.440892e-16  2.220446e-16       -0.0         -0.0
#
#    ineq_con008  ineq_con009   ineq_con013  ineq_con015  ineq_con030  ...  \
# 0     0.945819     0.825833  2.220446e-15      0.41338     1.409169  ...
#
#    ineq_con035  ineq_con036  ineq_con060  ineq_con062  ineq_con065  \
# 0     0.017247     0.949012     0.005688     0.474005     1.712764
#
#     ineq_con072  ineq_con081  ineq_con068  ineq_con031  ineq_con032
# 0  4.218847e-15     0.676783     0.015331     0.004844     0.183512
#
# [1 rows x 27 columns]
