# %% [markdown]
# # New constraints, high W: effect on LT solution evaluation
# Evaluate the LT solution with the new constraints, then turn up the W fraction to see which constraints change.

# %%
# Reload Process each time (keep editable install up-to-date)
# %load_ext autoreload
# %autoreload 2
from process.main import SingleRun
from process.io.plot_solutions import RunMetadata, plot_mfile_solutions, plot_mfile_solutions_constraints

# %% [markdown]
# Evaluate Process on LT solution, using modified constraints.

# %%
single_run = SingleRun("large_tokamak_once_through_mod_cons_IN.DAT")
single_run.run()
# Out:
# The IN.DAT file does not contain any obsolete variables.
#
#  **************************************************************************************************************
#  ************************************************** PROCESS ***************************************************
#  ************************************** Power Reactor Optimisation Code ***************************************
#  **************************************************************************************************************
#
#  Version : 3.1.0
#  Git Tag : v3.1.0-309-gaa36d2d8a
#  Git Branch : 3564-use-consistent-form-in-inequality-constraint-equations
#  Date : 06/03/2025 UTC
#  Time : 11:17
#  User : jon
#  Computer : jon-Precision-3560
#  Directory : /home/jon/code/notebooks/constraint_mods
#  Input : /home/jon/code/notebooks/constraint_mods/large_tokamak_once_through_mod_cons_IN.DAT
#  Run title : generic large tokamak
# ...

# %%
single_run = SingleRun("large_tokamak_once_through_mod_cons_high_W_IN.DAT")
single_run.run()
# Out:
# The IN.DAT file does not contain any obsolete variables.
#
#  **************************************************************************************************************
#  ************************************************** PROCESS ***************************************************
#  ************************************** Power Reactor Optimisation Code ***************************************
#  **************************************************************************************************************
#
#  Version : 3.1.0
#  Git Tag : v3.1.0-309-gaa36d2d8a
#  Git Branch : 3564-use-consistent-form-in-inequality-constraint-equations
#  Date : 06/03/2025 UTC
#  Time : 11:17
#  User : jon
#  Computer : jon-Precision-3560
#  Directory : /home/jon/code/notebooks/constraint_mods
#  Input : /home/jon/code/notebooks/constraint_mods/large_tokamak_once_through_mod_cons_high_W_IN.DAT
#  Run title : generic large tokamak
# ...

# %%
runs_metadata = [
    RunMetadata("large_tokamak_once_through_mod_cons_MFILE.DAT", "Original W (5e-6)"),
    RunMetadata(
        "large_tokamak_once_through_mod_cons_high_W_MFILE.DAT", "High W (1e-4)"
    ),
]
fig, once_through_df = plot_mfile_solutions_constraints(
    runs_metadata=runs_metadata,
    title="Modified constraints, LT solution evaluation, low and high W fraction",
)
