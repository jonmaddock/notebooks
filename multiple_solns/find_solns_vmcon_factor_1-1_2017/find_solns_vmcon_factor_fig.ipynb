# %% [markdown]
# # Find solns VMCON factor: baseline 2017
#
# Using VMCON with `factor = 1.1`, ~300 solutions were found. Are they all the same?
#
# Make the main result figure neater.

# %%
# Reload Process each time (keep editable install up-to-date)
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
from process.io import plot_solutions as ps

# %%
# Plot all solutions
data_dir = Path("data")
soln_files = list(data_dir.glob("*MFILE.DAT"))

# Order by number
soln_files = sorted(
    soln_files, key=lambda s: int(s.stem.removesuffix("_MFILE").removeprefix("sol_"))
)

runs_metadata = []
for soln_file in soln_files:
    soln_name = soln_file.stem.removesuffix("_MFILE")
    runs_metadata.append(ps.RunMetadata(soln_file, soln_name))

# Relative to 8 gives a nice range
abs_solns = ps.plot_mfile_solutions(
    runs_metadata,
    "Multistart local solutions to DEMO 2017 baseline, normalised to initial solution",
    diff_factor=True,
    relative_tag="sol_8",
    drop_f_values=True,
    plot_itvars=True,
    hide_legend=True
)

# %% [markdown]
# `vdalw` shows considerable variation (itvar024). This is max voltage across TF coil during quench (kV)

# %%
abs_solns["itvar024"].describe()
# Out:
# count    407.000000
# mean      21.273619
# std       11.745126
# min       11.292000
# 25%       14.743000
# 50%       17.679000
# 75%       22.673000
# max       99.694000
# Name: itvar024, dtype: float64

# %%
abs_solns
# Out:
#        tag              objf_name  norm_objf itvar001_name  itvar001
# 0    sol_0  net electrical output    -1.4022            bt    4.7251  \
# 1    sol_1  net electrical output    -1.4022            bt    4.7251
# 2    sol_2  net electrical output    -1.4022            bt    4.7251
# 3    sol_3  net electrical output    -1.4022            bt    4.7251
# 4    sol_4  net electrical output    -1.4022            bt    4.7251
# 5    sol_5  net electrical output    -1.4025            bt    4.7309
# 6    sol_6  net electrical output    -1.4025            bt    4.7309
# 7    sol_7  net electrical output    -1.4022            bt    4.7251
# 8    sol_8  net electrical output    -1.4025            bt    4.7303
# 9    sol_9  net electrical output    -1.4022            bt    4.7251
# 10  sol_10  net electrical output    -1.4022            bt    4.7251
# 11  sol_11  net electrical output    -1.4022            bt    4.7251
# 12  sol_12  net electrical output    -1.4022            bt    4.7251
# 13  sol_13  net electrical output    -1.4025            bt    4.7309
# 14  sol_14  net electrical output    -1.4022            bt    4.7251
# 15  sol_15  net electrical output    -1.4022            bt    4.7251
# 16  sol_16  net electrical output    -1.4022            bt    4.7251
# 17  sol_17  net electrical output    -1.4022            bt    4.7251
# 18  sol_18  net electrical output    -1.4022            bt    4.7251
#
#    itvar002_name  itvar002 itvar003_name  itvar003 itvar004_name  ...
# 0         rmajor    9.6153            te    14.542          beta  ...  \
# 1         rmajor    9.6153            te    14.542          beta  ...
# 2         rmajor    9.6153            te    14.542          beta  ...
# 3         rmajor    9.6153            te    14.542          beta  ...
# 4         rmajor    9.6153            te    14.542          beta  ...
# 5         rmajor    9.5970            te    14.535          beta  ...
# 6         rmajor    9.5970            te    14.535          beta  ...
# 7         rmajor    9.6153            te    14.542          beta  ...
# 8         rmajor    9.5989            te    14.536          beta  ...
# 9         rmajor    9.6153            te    14.542          beta  ...
# 10        rmajor    9.6153            te    14.542          beta  ...
# 11        rmajor    9.6153            te    14.542          beta  ...
# 12        rmajor    9.6153            te    14.542          beta  ...
# 13        rmajor    9.5970            te    14.535          beta  ...
# 14        rmajor    9.6153            te    14.542          beta  ...
# 15        rmajor    9.6153            te    14.542          beta  ...
# 16        rmajor    9.6153            te    14.542          beta  ...
# 17        rmajor    9.6153            te    14.542          beta  ...
# 18        rmajor    9.6153            te    14.542          beta  ...
#
#     itvar043_name  itvar043  itvar044_name itvar044  itvar045_name itvar045
# 0        fimp(13)  0.000820       dr_tf_wp      0.5         fgwped     0.72  \
# 1        fimp(13)  0.000820       dr_tf_wp      0.5         fgwped     0.72
# 2        fimp(13)  0.000820       dr_tf_wp      0.5         fgwped     0.72
# 3        fimp(13)  0.000820       dr_tf_wp      0.5         fgwped     0.72
# 4        fimp(13)  0.000820       dr_tf_wp      0.5         fgwped     0.72
# 5        fimp(13)  0.000821       dr_tf_wp      0.5         fgwped     0.72
# 6        fimp(13)  0.000821       dr_tf_wp      0.5         fgwped     0.72
# 7        fimp(13)  0.000820       dr_tf_wp      0.5         fgwped     0.72
# 8        fimp(13)  0.000821       dr_tf_wp      0.5         fgwped     0.72
# 9        fimp(13)  0.000820       dr_tf_wp      0.5         fgwped     0.72
# 10       fimp(13)  0.000820       dr_tf_wp      0.5         fgwped     0.72
# 11       fimp(13)  0.000820       dr_tf_wp      0.5         fgwped     0.72
# 12       fimp(13)  0.000820       dr_tf_wp      0.5         fgwped     0.72
# 13       fimp(13)  0.000821       dr_tf_wp      0.5         fgwped     0.72
# 14       fimp(13)  0.000820       dr_tf_wp      0.5         fgwped     0.72
# 15       fimp(13)  0.000820       dr_tf_wp      0.5         fgwped     0.72
# 16       fimp(13)  0.000820       dr_tf_wp      0.5         fgwped     0.72
# 17       fimp(13)  0.000820       dr_tf_wp      0.5         fgwped     0.72
# 18       fimp(13)  0.000820       dr_tf_wp      0.5         fgwped     0.72
#
#     itvar046_name itvar046  itvar047_name itvar047
# 0         fbmaxcs  0.73763           fne0  0.48113
# 1         fbmaxcs  0.73763           fne0  0.48113
# 2         fbmaxcs  0.73763           fne0  0.48113
# 3         fbmaxcs  0.73763           fne0  0.48113
# 4         fbmaxcs  0.73763           fne0  0.48113
# 5         fbmaxcs  0.74260           fne0  0.48113
# 6         fbmaxcs  0.74260           fne0  0.48113
# 7         fbmaxcs  0.73763           fne0  0.48113
# 8         fbmaxcs  0.74213           fne0  0.48113
# 9         fbmaxcs  0.73763           fne0  0.48113
# 10        fbmaxcs  0.73763           fne0  0.48113
# 11        fbmaxcs  0.73763           fne0  0.48113
# 12        fbmaxcs  0.73763           fne0  0.48113
# 13        fbmaxcs  0.74260           fne0  0.48113
# 14        fbmaxcs  0.73763           fne0  0.48113
# 15        fbmaxcs  0.73763           fne0  0.48113
# 16        fbmaxcs  0.73763           fne0  0.48113
# 17        fbmaxcs  0.73763           fne0  0.48113
# 18        fbmaxcs  0.73763           fne0  0.48113
#
# [19 rows x 97 columns]
