# %% [markdown]
# ## Plotting differences in solutions across regression tests
#
# How different are the regression test solutions from different solvers? Do any achieve a lower FOM? It would be useful to visualise this on a single plot.

# %%
from plot_solvers import compare_regression_test, compare_regression_tests, clear_unwanted_output
from pathlib import Path
import process
import pandas as pd
import matplotlib.pyplot as plt

# Should reload Process each time (keep editable install up-to-date)
# %load_ext autoreload
# %aimport process, plot_solvers
# %autoreload 1

# %% [markdown]
# ## Compare all regression tests

# %%
results_df = compare_regression_tests(["legacy-vmcon", "nlopt"], rerun_tests=False)
# Out:
#
#  **************************************************************************************************************
#  ************************************************** PROCESS ***************************************************
#  ************************************** Power Reactor Optimisation Code ***************************************
#  **************************************************************************************************************
#
#    Program :
#    Version : 2.4.0   Release Date :: 2022-05-18
#    Tag No. : v2.4.0-529-g85cdde289 code contains untracked changes
#     Branch : nlopt-test-2
#    Git log : Simplify logging to process.log
#  Date/time :  4 Apr 2023 15:13:40 +01:00(hh:mm) UTC
#       User : jon
#   Computer : jon-Precision-3560
#  Directory : /home/jon/code/notebooks/nlopt_process
#      Input : /home/jon/code/notebooks/nlopt_process/data/QH_mode_nlopt_IN.DAT
#  Run title : Example QH-mode plasma scenario
# ...

# %% [markdown]
# CS fatigue looks like it might be quite different. Let's plot it.

# %%
compare_regression_test("cs_fatigue_and_hts_REBCO", ["legacy-vmcon", "nlopt"])
# Out:
# /home/jon/code/notebooks/nlopt_process/plot_solvers.py:494: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0].set_xticklabels(opt_params_labels)
# /home/jon/code/notebooks/nlopt_process/plot_solvers.py:515: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[1].set_xticklabels(norm_objf_label)
#                               tag  norm_objf    xcm001    xcm002    xcm003  \
# 1  cs_fatigue_and_hts_REBCO_nlopt   0.168974  0.068832  0.164761  0.242119
#
#      xcm004    xcm005  xcm006     xcm007    xcm008  ...  xcm033    xcm034  \
# 1 -0.002047 -0.098176     0.0  17.188713  0.166411  ...     0.0  22.95233
#
#       xcm035     xcm036     xcm037    xcm038    xcm039  xcm040  xcm041  xcm042
# 1  91.045402  111.10104  34.151288  1.260067  0.375466     0.0  -2.281     0.0
#
# [1 rows x 44 columns]
