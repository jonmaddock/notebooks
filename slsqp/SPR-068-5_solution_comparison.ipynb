# %% [markdown]
# # Plot old VMCON eqs and SLSQP ineqs solutions

# %%
# Reload Process each time (keep editable install up-to-date)
# %load_ext autoreload
# %autoreload 2

from process.io.plot_solutions import RunMetadata, plot_mfile_solutions
from pathlib import Path

# %%
data_dir = Path.cwd()
runs_metadata = [
    RunMetadata(
        data_dir / "SPR-068-5_old_vmcon_f_values_removed_MFILE.DAT",
        "SPR-068-5 eqs old VMCON",
    ),
    RunMetadata(data_dir / "SPR-068-5_ineqs_3_MFILE.DAT", "SPR-068-5 ineqs SLSQP"),
]

fig, df = plot_mfile_solutions(
    runs_metadata,
    "SPR-068-5 solutions using equality and inequality constraints, different solvers",
    normalisation_type="range",
)
df
# Out:
# /home/jon/anaconda3/envs/process-uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/jon/anaconda3/envs/process-uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/jon/anaconda3/envs/process-uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# Absolute values:

# %%
fig, df = plot_mfile_solutions(
    runs_metadata,
    "SPR-068-5 solutions using equality and inequality constraints, different solvers",
    normalisation_type=None,
)
fig.savefig("spr-068-5_solution_comparison.pdf")
df
# Out:
# /home/jon/anaconda3/envs/process-uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/jon/anaconda3/envs/process-uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/jon/anaconda3/envs/process-uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# Plot with MFILE with f-value opt params left in.

# %%
runs_metadata = [
    RunMetadata(
        data_dir / "SPR-068-5_old_vmcon_MFILE.DAT",
        "SPR-068-5 eqs old VMCON",
    ),
    RunMetadata(data_dir / "SPR-068-5_ineqs_MFILE.DAT", "SPR-068-5 ineqs SLSQP"),
]

fig, df = plot_mfile_solutions(
    runs_metadata,
    "SPR-068-5 solutions using equality and inequality constraints, different solvers",
    normalisation_type="range",
)
df
# Out:
# /home/jon/anaconda3/envs/process-uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/jon/anaconda3/envs/process-uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/jon/anaconda3/envs/process-uq/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...
