# %% [markdown]
# # COBYLA on regression tests
#
# Using nlopt, run Process's regression tests.

# %%
# Reload Process each time (keep editable install up-to-date)
# %load_ext autoreload
# %autoreload 2

from process.io import plot_solutions as ps

# %% [markdown]
# ## Single regression run
#
# Run a single regression run using scipy's SLSQP. Check the values of the constraints.

# %%
results_df = ps.run_and_print("baseline_jan_2017", "nlopt", rerun=True)
# Out:
# The IN.DAT file does not contain any obsolete variables.
#  The total number of constraints is counted automatically and does not need to be stated in IN.DAT.
#  The number of iteration variables is counted automatically and does not need to be stated in IN.DAT.
#
#  **************************************************************************************************************
#  ************************************************** PROCESS ***************************************************
#  ************************************** Power Reactor Optimisation Code ***************************************
#  **************************************************************************************************************
#
#    Program :
#    Version : 2.4.0   Release Date :: 2022-05-18
#    Tag No. : v2.4.0-913-g759a689f1 code contains untracked changes
#     Branch : 1813-implement-nlopt-s-slsqp-solver
#  Warning in routine OCMMNT :
#   Git log : Overwrite regression references for |Merge branch |1829-numba-performance-warnings-in-sctfcoil| into |develop||
# This is longer than 110 columns.
#    Git log : Overwrite regression references for |Merge branch |1829-numba-performance-warnings-in-sctfcoil| into |develop||
#  Date/time :  5 May 2023 16:06:23 +01:00(hh:mm) UTC
#       User : jon
#   Computer : jon-Precision-3560
#  Directory : /home/jon/code/notebooks/slsqp_process/cobyla
#      Input : /home/jon/code/notebooks/slsqp_process/cobyla/data/baseline_jan_2017_nlopt_IN.DAT
#  Run title : Run Title (change this line using input variable 'runtitle')
#   Run type : Reactor concept design: Pulsed tokamak model, (c) CCFE
#
#  **************************************************************************************************************
#
#    Equality constraints : 18
#  Inequality constraints : 00
#       Total constraints : 18
#     Iteration variables : 32
#          Max iterations : 200
#        Figure of merit  : +01  -- minimise major radius
#   Convergence parameter : 1.00E-08
#
#  **************************************************************************************************************
#  Warning in routine OCMMNT :
#   Git log : Overwrite regression references for |Merge branch |1829-numba-performance-warnings-in-sctfcoil| into |develop||
# This is longer than 110 columns.
# Evaluation 1, objective function = 1.81440e+00, constraint residuals = 8.629e-01
# Evaluation 2, objective function = 1.81440e+00, constraint residuals = 6.779e+00
# Evaluation 3, objective function = 2.45940e+00, constraint residuals = 3.930e+00
# Evaluation 4, objective function = 1.81440e+00, constraint residuals = 2.426e+00
# Evaluation 5, objective function = 1.81440e+00, constraint residuals = 1.152e+00
# Evaluation 6, objective function = 1.81440e+00, constraint residuals = 5.149e+00
# Evaluation 7, objective function = 1.81440e+00, constraint residuals = 9.013e-01
# Evaluation 8, objective function = 1.81440e+00, constraint residuals = 8.884e-01
# Evaluation 9, objective function = 1.81440e+00, constraint residuals = 8.790e+00
# Evaluation 10, objective function = 1.81440e+00, constraint residuals = 1.113e+00
# Evaluation 11, objective function = 1.81440e+00, constraint residuals = 3.594e+00
# Evaluation 12, objective function = 1.81440e+00, constraint residuals = 1.203e+00
# Evaluation 13, objective function = 1.81440e+00, constraint residuals = 5.117e+00
# Evaluation 14, objective function = 1.81440e+00, constraint residuals = 9.868e-01
# Evaluation 15, objective function = 1.81440e+00, constraint residuals = 2.744e+00
# Evaluation 16, objective function = 1.81440e+00, constraint residuals = 9.093e-01
# Evaluation 17, objective function = 1.81440e+00, constraint residuals = 9.111e-01
# Evaluation 18, objective function = 1.81440e+00, constraint residuals = 9.251e-01
# Evaluation 19, objective function = 1.81440e+00, constraint residuals = 8.646e-01
# Evaluation 20, objective function = 1.81440e+00, constraint residuals = 2.857e+00
# Evaluation 21, objective function = 1.81440e+00, constraint residuals = 9.002e-01
# Evaluation 22, objective function = 1.81440e+00, constraint residuals = 8.639e-01
# Evaluation 23, objective function = 1.81440e+00, constraint residuals = 9.142e-01
# Evaluation 24, objective function = 1.81440e+00, constraint residuals = 8.108e-01
# Evaluation 25, objective function = 1.81440e+00, constraint residuals = 8.436e-01
# Evaluation 26, objective function = 1.81440e+00, constraint residuals = 9.373e-01
# Evaluation 27, objective function = 1.81440e+00, constraint residuals = 8.810e-01
# Evaluation 28, objective function = 1.81440e+00, constraint residuals = 1.614e+00
# Evaluation 29, objective function = 1.81440e+00, constraint residuals = 8.630e-01
# Evaluation 30, objective function = 1.81440e+00, constraint residuals = 9.114e-01
# Evaluation 31, objective function = 1.81440e+00, constraint residuals = 6.172e-01
# Evaluation 32, objective function = 1.81440e+00, constraint residuals = 8.267e-01
# Evaluation 33, objective function = 1.81440e+00, constraint residuals = 9.407e-01
# Evaluation 34, objective function = 1.59579e+00, constraint residuals = 1.164e+00
# Evaluation 35, objective function = 1.72889e+00, constraint residuals = 5.831e-01
# Evaluation 36, objective function = 1.78076e+00, constraint residuals = 4.966e-01
# Evaluation 37, objective function = 1.72889e+00, constraint residuals = 1.256e+00
# Evaluation 38, objective function = 1.74749e+00, constraint residuals = 3.953e-01
# Evaluation 39, objective function = 1.82670e+00, constraint residuals = 6.605e-01
# Evaluation 40, objective function = 1.74749e+00, constraint residuals = 1.160e+00
# Evaluation 41, objective function = 1.92180e+00, constraint residuals = 1.406e+00
# Evaluation 42, objective function = 1.74749e+00, constraint residuals = 4.005e-01
# Evaluation 43, objective function = 1.95351e+00, constraint residuals = 5.944e-01
# Evaluation 44, objective function = 1.81076e+00, constraint residuals = 7.001e-01
# Evaluation 45, objective function = 1.99149e+00, constraint residuals = 1.027e+00
# Evaluation 46, objective function = 1.74709e+00, constraint residuals = 5.084e-01
# Evaluation 47, objective function = 1.95175e+00, constraint residuals = 3.702e-01
# Evaluation 48, objective function = 1.74749e+00, constraint residuals = 4.119e-01
# Evaluation 49, objective function = 1.82305e+00, constraint residuals = 5.736e-01
# Evaluation 50, objective function = 1.74749e+00, constraint residuals = 4.252e-01
# Evaluation 51, objective function = 1.94310e+00, constraint residuals = 3.241e-01
# Evaluation 52, objective function = 1.74749e+00, constraint residuals = 4.355e-01
# Evaluation 53, objective function = 1.94328e+00, constraint residuals = 3.234e-01
# Evaluation 54, objective function = 1.74749e+00, constraint residuals = 3.940e-01
# Evaluation 55, objective function = 1.94402e+00, constraint residuals = 3.244e-01
# Evaluation 56, objective function = 1.74749e+00, constraint residuals = 4.171e-01
# Evaluation 57, objective function = 1.94974e+00, constraint residuals = 2.668e-01
# Evaluation 58, objective function = 2.13667e+00, constraint residuals = 1.446e+00
# Evaluation 59, objective function = 1.92545e+00, constraint residuals = 1.498e+00
# Evaluation 60, objective function = 2.11327e+00, constraint residuals = 1.392e+00
# Evaluation 61, objective function = 1.99182e+00, constraint residuals = 1.460e+00
# Evaluation 62, objective function = 2.10789e+00, constraint residuals = 1.460e+00
# Evaluation 63, objective function = 1.94974e+00, constraint residuals = 3.184e-01
# Evaluation 64, objective function = 2.10814e+00, constraint residuals = 1.462e+00
# Evaluation 65, objective function = 1.94974e+00, constraint residuals = 3.078e-01
# Evaluation 66, objective function = 2.10814e+00, constraint residuals = 1.462e+00
# Evaluation 67, objective function = 1.94986e+00, constraint residuals = 2.727e-01
# Evaluation 68, objective function = 2.10787e+00, constraint residuals = 1.471e+00
# Evaluation 69, objective function = 1.95006e+00, constraint residuals = 4.035e-01
# Evaluation 70, objective function = 2.05967e+00, constraint residuals = 7.012e-01
# Evaluation 71, objective function = 1.94973e+00, constraint residuals = 2.669e-01
# Evaluation 72, objective function = 2.10035e+00, constraint residuals = 4.009e-01
# Evaluation 73, objective function = 1.95246e+00, constraint residuals = 1.565e+00
# Evaluation 74, objective function = 2.10538e+00, constraint residuals = 6.634e-01
# Evaluation 75, objective function = 1.94737e+00, constraint residuals = 5.172e-01
# Evaluation 76, objective function = 2.06654e+00, constraint residuals = 4.375e-01
# Evaluation 77, objective function = 1.95182e+00, constraint residuals = 3.336e-01
# Evaluation 78, objective function = 2.07050e+00, constraint residuals = 6.170e-01
# Evaluation 79, objective function = 1.96164e+00, constraint residuals = 1.896e+00
# Evaluation 80, objective function = 2.04914e+00, constraint residuals = 8.694e-01
# Evaluation 81, objective function = 1.94659e+00, constraint residuals = 3.096e-01
# Evaluation 82, objective function = 2.02021e+00, constraint residuals = 5.846e-01
# Evaluation 83, objective function = 1.98760e+00, constraint residuals = 5.070e-01
# Evaluation 84, objective function = 2.01287e+00, constraint residuals = 5.375e-01
# Evaluation 85, objective function = 1.94178e+00, constraint residuals = 6.329e-01
# Evaluation 86, objective function = 2.04890e+00, constraint residuals = 4.410e-01
# Evaluation 87, objective function = 1.95188e+00, constraint residuals = 6.392e-01
# Evaluation 88, objective function = 2.05170e+00, constraint residuals = 3.993e-01
# Evaluation 89, objective function = 1.95034e+00, constraint residuals = 2.952e-01
# Evaluation 90, objective function = 2.13962e+00, constraint residuals = 2.444e-01
# Evaluation 91, objective function = 1.91381e+00, constraint residuals = 4.640e-01
# Evaluation 92, objective function = 2.00512e+00, constraint residuals = 7.131e-01
# Evaluation 93, objective function = 2.07305e+00, constraint residuals = 8.705e-01
# Evaluation 94, objective function = 2.10568e+00, constraint residuals = 1.929e-01
# Evaluation 95, objective function = 1.96605e+00, constraint residuals = 4.940e-01
# Evaluation 96, objective function = 2.13297e+00, constraint residuals = 1.878e-01
# Evaluation 97, objective function = 2.21038e+00, constraint residuals = 3.075e-01
# Evaluation 98, objective function = 2.15858e+00, constraint residuals = 1.378e+00
# Evaluation 99, objective function = 2.25619e+00, constraint residuals = 5.295e-01
# Evaluation 100, objective function = 2.18893e+00, constraint residuals = 8.896e-01
# Evaluation 101, objective function = 2.21688e+00, constraint residuals = 1.138e-01
# Evaluation 102, objective function = 2.08895e+00, constraint residuals = 3.328e-01
# Evaluation 103, objective function = 2.19123e+00, constraint residuals = 5.759e-01
# Evaluation 104, objective function = 2.09125e+00, constraint residuals = 9.718e-02
# Evaluation 105, objective function = 1.97192e+00, constraint residuals = 2.199e-01
# Evaluation 106, objective function = 2.09125e+00, constraint residuals = 1.339e-01
# Evaluation 107, objective function = 1.99930e+00, constraint residuals = 2.078e-01
# Evaluation 108, objective function = 2.13353e+00, constraint residuals = 1.455e+00
# Evaluation 109, objective function = 2.03085e+00, constraint residuals = 3.321e-01
# Evaluation 110, objective function = 2.15200e+00, constraint residuals = 7.365e-01
# Evaluation 111, objective function = 1.99512e+00, constraint residuals = 2.144e-01
# Evaluation 112, objective function = 2.11423e+00, constraint residuals = 4.128e-01
# Evaluation 113, objective function = 1.92547e+00, constraint residuals = 6.401e-01
# Evaluation 114, objective function = 2.09053e+00, constraint residuals = 3.609e-01
# Evaluation 115, objective function = 1.97137e+00, constraint residuals = 5.270e-01
# Evaluation 116, objective function = 2.06983e+00, constraint residuals = 3.027e-01
# Evaluation 117, objective function = 1.98344e+00, constraint residuals = 2.887e-01
# Evaluation 118, objective function = 2.06770e+00, constraint residuals = 6.639e-01
# Evaluation 119, objective function = 1.97033e+00, constraint residuals = 5.347e-01
# Evaluation 120, objective function = 2.09525e+00, constraint residuals = 6.224e-01
# Evaluation 121, objective function = 1.97810e+00, constraint residuals = 1.931e-01
# Evaluation 122, objective function = 2.07119e+00, constraint residuals = 2.197e+00
# Evaluation 123, objective function = 1.95277e+00, constraint residuals = 3.895e-01
# Evaluation 124, objective function = 2.08468e+00, constraint residuals = 4.648e-01
# Evaluation 125, objective function = 1.98035e+00, constraint residuals = 2.434e-01
# Evaluation 126, objective function = 2.10458e+00, constraint residuals = 1.250e+00
# Evaluation 127, objective function = 1.96792e+00, constraint residuals = 4.963e-01
# Evaluation 128, objective function = 2.15434e+00, constraint residuals = 6.478e-01
# Evaluation 129, objective function = 1.96542e+00, constraint residuals = 2.815e-01
# Evaluation 130, objective function = 2.08105e+00, constraint residuals = 4.973e-01
# Evaluation 131, objective function = 1.96372e+00, constraint residuals = 3.061e-01
# Evaluation 132, objective function = 2.08033e+00, constraint residuals = 9.191e-01
# Evaluation 133, objective function = 1.94994e+00, constraint residuals = 2.911e-01
# Evaluation 134, objective function = 2.03061e+00, constraint residuals = 3.028e-01
# Evaluation 135, objective function = 1.94274e+00, constraint residuals = 3.892e-01
# Evaluation 136, objective function = 2.08732e+00, constraint residuals = 4.835e-01
# Evaluation 137, objective function = 1.95283e+00, constraint residuals = 3.881e-01
# Evaluation 138, objective function = 2.08159e+00, constraint residuals = 1.038e+00
# Evaluation 139, objective function = 1.94807e+00, constraint residuals = 3.197e-01
# Evaluation 140, objective function = 2.11223e+00, constraint residuals = 6.740e-01
# Evaluation 141, objective function = 1.95599e+00, constraint residuals = 2.275e-01
# Evaluation 142, objective function = 2.12896e+00, constraint residuals = 9.217e-01
# Evaluation 143, objective function = 1.95843e+00, constraint residuals = 2.389e-01
# Evaluation 144, objective function = 2.10514e+00, constraint residuals = 1.977e+00
# Evaluation 145, objective function = 1.96251e+00, constraint residuals = 1.350e-01
# Evaluation 146, objective function = 2.04786e+00, constraint residuals = 1.132e+00
# Evaluation 147, objective function = 1.96027e+00, constraint residuals = 1.386e-01
# Evaluation 148, objective function = 2.13433e+00, constraint residuals = 1.628e+00
# Evaluation 149, objective function = 1.95702e+00, constraint residuals = 2.422e-01
# Evaluation 150, objective function = 2.03829e+00, constraint residuals = 4.089e-01
# Evaluation 151, objective function = 1.93010e+00, constraint residuals = 4.952e-01
# Evaluation 152, objective function = 2.09489e+00, constraint residuals = 8.157e-01
# Evaluation 153, objective function = 1.94885e+00, constraint residuals = 2.839e-01
# Evaluation 154, objective function = 1.99879e+00, constraint residuals = 1.108e+00
# Evaluation 155, objective function = 1.95972e+00, constraint residuals = 2.855e-01
# Evaluation 156, objective function = 2.11729e+00, constraint residuals = 6.217e-01
# Evaluation 157, objective function = 1.89240e+00, constraint residuals = 3.671e-01
# Evaluation 158, objective function = 2.09065e+00, constraint residuals = 4.248e-01
# Evaluation 159, objective function = 1.96962e+00, constraint residuals = 2.117e-01
# Evaluation 160, objective function = 2.09121e+00, constraint residuals = 4.670e-01
# Evaluation 161, objective function = 1.97833e+00, constraint residuals = 1.504e-01
# Evaluation 162, objective function = 2.09121e+00, constraint residuals = 9.393e-01
# Evaluation 163, objective function = 1.98349e+00, constraint residuals = 1.187e-01
# Evaluation 164, objective function = 1.91570e+00, constraint residuals = 8.767e-01
# Evaluation 165, objective function = 1.97351e+00, constraint residuals = 9.129e-01
# Evaluation 166, objective function = 1.92463e+00, constraint residuals = 3.713e-01
# Evaluation 167, objective function = 1.98955e+00, constraint residuals = 4.210e-01
# Evaluation 168, objective function = 1.92253e+00, constraint residuals = 3.831e-01
# Evaluation 169, objective function = 1.96663e+00, constraint residuals = 1.115e+00
# Evaluation 170, objective function = 1.91943e+00, constraint residuals = 3.326e-01
# Evaluation 171, objective function = 1.95246e+00, constraint residuals = 5.330e-01
# Evaluation 172, objective function = 1.91811e+00, constraint residuals = 3.649e-01
# Evaluation 173, objective function = 1.98396e+00, constraint residuals = 8.545e-01
# Evaluation 174, objective function = 1.91530e+00, constraint residuals = 3.552e-01
# Evaluation 175, objective function = 1.99337e+00, constraint residuals = 7.973e-01
# Evaluation 176, objective function = 1.99369e+00, constraint residuals = 5.919e-01
# Evaluation 177, objective function = 2.00234e+00, constraint residuals = 2.082e-01
# Evaluation 178, objective function = 1.97784e+00, constraint residuals = 7.134e-01
# Evaluation 179, objective function = 1.90012e+00, constraint residuals = 5.412e-01
# Evaluation 180, objective function = 1.96910e+00, constraint residuals = 1.205e+00
# Evaluation 181, objective function = 1.84027e+00, constraint residuals = 8.695e-01
# Evaluation 182, objective function = 1.97960e+00, constraint residuals = 6.618e-01
# Evaluation 183, objective function = 1.92190e+00, constraint residuals = 3.362e-01
# Evaluation 184, objective function = 1.95860e+00, constraint residuals = 8.290e-01
# Evaluation 185, objective function = 1.90595e+00, constraint residuals = 4.301e-01
# Evaluation 186, objective function = 1.98188e+00, constraint residuals = 5.518e-01
# Evaluation 187, objective function = 1.89710e+00, constraint residuals = 8.766e-01
# Evaluation 188, objective function = 1.98859e+00, constraint residuals = 4.490e-01
# Evaluation 189, objective function = 2.00437e+00, constraint residuals = 1.839e-01
# Evaluation 190, objective function = 1.96526e+00, constraint residuals = 1.832e+00
# Evaluation 191, objective function = 2.01448e+00, constraint residuals = 1.917e-01
# Evaluation 192, objective function = 1.98876e+00, constraint residuals = 1.098e+00
# Evaluation 193, objective function = 1.98274e+00, constraint residuals = 2.433e-01
# Evaluation 194, objective function = 1.90872e+00, constraint residuals = 7.085e-01
# Evaluation 195, objective function = 1.90828e+00, constraint residuals = 4.305e-01
# Evaluation 196, objective function = 1.97436e+00, constraint residuals = 6.124e-01
# Evaluation 197, objective function = 1.90854e+00, constraint residuals = 2.952e-01
# Evaluation 198, objective function = 1.97266e+00, constraint residuals = 4.241e-01
# Evaluation 199, objective function = 2.03780e+00, constraint residuals = 5.817e-01
# Evaluation 200, objective function = 1.99240e+00, constraint residuals = 2.459e-01
# Evaluation 201, objective function = 1.87836e+00, constraint residuals = 7.695e-01
# Evaluation 202, objective function = 1.96462e+00, constraint residuals = 1.053e+00
# Evaluation 203, objective function = 1.99693e+00, constraint residuals = 6.008e-01
# Evaluation 204, objective function = 1.98846e+00, constraint residuals = 2.591e-01
# Evaluation 205, objective function = 1.94627e+00, constraint residuals = 4.593e-01
# Evaluation 206, objective function = 1.98346e+00, constraint residuals = 9.833e-01
# Evaluation 207, objective function = 1.95469e+00, constraint residuals = 3.856e-01
# Evaluation 208, objective function = 1.98336e+00, constraint residuals = 1.182e+00
# Evaluation 209, objective function = 1.99961e+00, constraint residuals = 2.290e-01
# Evaluation 210, objective function = 1.98340e+00, constraint residuals = 1.184e+00
# Evaluation 211, objective function = 1.95632e+00, constraint residuals = 2.302e-01
# Evaluation 212, objective function = 1.88102e+00, constraint residuals = 1.233e+00
# Evaluation 213, objective function = 2.12806e+00, constraint residuals = 1.375e-01
# Evaluation 214, objective function = 1.81267e+00, constraint residuals = 1.233e+00
# Evaluation 215, objective function = 2.07134e+00, constraint residuals = 4.170e-01
# Evaluation 216, objective function = 1.97653e+00, constraint residuals = 4.927e-01
# Evaluation 217, objective function = 1.94695e+00, constraint residuals = 4.828e-01
# Evaluation 218, objective function = 1.97635e+00, constraint residuals = 3.877e-01
# Evaluation 219, objective function = 2.00184e+00, constraint residuals = 1.342e-01
# Evaluation 220, objective function = 1.97682e+00, constraint residuals = 5.670e-01
# Evaluation 221, objective function = 1.94991e+00, constraint residuals = 1.925e-01
# Evaluation 222, objective function = 1.98135e+00, constraint residuals = 2.550e-01
# Evaluation 223, objective function = 1.92834e+00, constraint residuals = 3.745e-01
# Evaluation 224, objective function = 1.98252e+00, constraint residuals = 6.609e-01
# Evaluation 225, objective function = 1.97693e+00, constraint residuals = 5.560e-01
# Evaluation 226, objective function = 1.92842e+00, constraint residuals = 3.526e-01
# Evaluation 227, objective function = 1.98263e+00, constraint residuals = 4.728e-01
# Evaluation 228, objective function = 1.95995e+00, constraint residuals = 2.752e-01
# Evaluation 229, objective function = 1.97722e+00, constraint residuals = 1.072e+00
# Evaluation 230, objective function = 1.94581e+00, constraint residuals = 3.661e-01
# Evaluation 231, objective function = 1.97323e+00, constraint residuals = 8.581e-01
# Evaluation 232, objective function = 1.95284e+00, constraint residuals = 2.427e-01
# Evaluation 233, objective function = 1.95753e+00, constraint residuals = 8.355e-01
# Evaluation 234, objective function = 1.95241e+00, constraint residuals = 2.524e-01
# Evaluation 235, objective function = 2.00258e+00, constraint residuals = 4.327e-01
# Evaluation 236, objective function = 2.00207e+00, constraint residuals = 2.320e-01
# Evaluation 237, objective function = 1.96314e+00, constraint residuals = 4.521e-01
# Evaluation 238, objective function = 2.01282e+00, constraint residuals = 4.747e-01
# Evaluation 239, objective function = 1.98520e+00, constraint residuals = 6.841e-01
# Evaluation 240, objective function = 1.94724e+00, constraint residuals = 2.718e-01
# Evaluation 241, objective function = 1.95079e+00, constraint residuals = 4.869e-01
# Evaluation 242, objective function = 1.94748e+00, constraint residuals = 2.721e-01
# Evaluation 243, objective function = 1.93538e+00, constraint residuals = 4.979e-01
# Evaluation 244, objective function = 1.94692e+00, constraint residuals = 2.753e-01
# Evaluation 245, objective function = 2.03013e+00, constraint residuals = 4.255e-01
# Evaluation 246, objective function = 1.94741e+00, constraint residuals = 2.669e-01
# Evaluation 247, objective function = 1.91831e+00, constraint residuals = 1.224e+00
# Evaluation 248, objective function = 1.95144e+00, constraint residuals = 2.406e-01
# Evaluation 249, objective function = 1.98195e+00, constraint residuals = 8.597e-01
# Evaluation 250, objective function = 1.95312e+00, constraint residuals = 2.461e-01
# Evaluation 251, objective function = 1.95802e+00, constraint residuals = 3.324e-01
# Evaluation 252, objective function = 1.92398e+00, constraint residuals = 7.929e-01
# Evaluation 253, objective function = 1.97700e+00, constraint residuals = 6.036e-01
# Evaluation 254, objective function = 1.99373e+00, constraint residuals = 6.026e-01
# Evaluation 255, objective function = 1.95813e+00, constraint residuals = 3.665e-01
# Evaluation 256, objective function = 1.95604e+00, constraint residuals = 2.101e-01
# Evaluation 257, objective function = 1.95944e+00, constraint residuals = 7.036e-01
# Evaluation 258, objective function = 1.95251e+00, constraint residuals = 2.350e-01
# Evaluation 259, objective function = 1.95958e+00, constraint residuals = 8.720e-01
# Evaluation 260, objective function = 1.94196e+00, constraint residuals = 2.663e-01
# Evaluation 261, objective function = 1.98426e+00, constraint residuals = 7.642e-01
# Evaluation 262, objective function = 1.96156e+00, constraint residuals = 2.137e-01
# Evaluation 263, objective function = 1.99178e+00, constraint residuals = 6.748e-01
# Evaluation 264, objective function = 1.96351e+00, constraint residuals = 2.303e-01
# Evaluation 265, objective function = 1.98275e+00, constraint residuals = 8.548e-01
# Evaluation 266, objective function = 1.96260e+00, constraint residuals = 2.149e-01
# Evaluation 267, objective function = 1.96034e+00, constraint residuals = 5.092e-01
# Evaluation 268, objective function = 1.96179e+00, constraint residuals = 2.360e-01
# Evaluation 269, objective function = 1.97002e+00, constraint residuals = 8.274e-01
# Evaluation 270, objective function = 1.96380e+00, constraint residuals = 2.219e-01
# Evaluation 271, objective function = 2.00247e+00, constraint residuals = 1.113e+00
# Evaluation 272, objective function = 2.02357e+00, constraint residuals = 3.007e-01
# Evaluation 273, objective function = 1.98740e+00, constraint residuals = 7.649e-01
# Evaluation 274, objective function = 1.96341e+00, constraint residuals = 1.985e-01
# Evaluation 275, objective function = 1.96568e+00, constraint residuals = 1.160e+00
# Evaluation 276, objective function = 2.04128e+00, constraint residuals = 2.284e-01
# Evaluation 277, objective function = 1.98661e+00, constraint residuals = 6.536e-01
# Evaluation 278, objective function = 1.96341e+00, constraint residuals = 2.177e-01
# Evaluation 279, objective function = 1.99513e+00, constraint residuals = 8.605e-01
# Evaluation 280, objective function = 1.95974e+00, constraint residuals = 1.904e-01
# Evaluation 281, objective function = 1.97138e+00, constraint residuals = 6.549e-01
# Evaluation 282, objective function = 1.95906e+00, constraint residuals = 2.158e-01
# Evaluation 283, objective function = 1.97300e+00, constraint residuals = 4.614e-01
# Evaluation 284, objective function = 1.96007e+00, constraint residuals = 2.268e-01
# Evaluation 285, objective function = 1.98166e+00, constraint residuals = 9.582e-01
# Evaluation 286, objective function = 1.96346e+00, constraint residuals = 2.289e-01
# Evaluation 287, objective function = 1.96512e+00, constraint residuals = 1.088e+00
# Evaluation 288, objective function = 1.99409e+00, constraint residuals = 4.251e-01
# Evaluation 289, objective function = 1.96237e+00, constraint residuals = 8.982e-01
# Evaluation 290, objective function = 2.09420e+00, constraint residuals = 4.730e-01
# Evaluation 291, objective function = 1.96329e+00, constraint residuals = 1.294e+00
# Evaluation 292, objective function = 1.94524e+00, constraint residuals = 2.990e-01
# Evaluation 293, objective function = 1.95226e+00, constraint residuals = 7.669e-01
# Evaluation 294, objective function = 1.96077e+00, constraint residuals = 4.488e-01
# Evaluation 295, objective function = 1.94243e+00, constraint residuals = 6.169e-01
# Evaluation 296, objective function = 1.96338e+00, constraint residuals = 3.181e-01
# Evaluation 297, objective function = 1.97690e+00, constraint residuals = 4.470e-01
# Evaluation 298, objective function = 1.96300e+00, constraint residuals = 1.802e-01
# Evaluation 299, objective function = 1.94422e+00, constraint residuals = 7.945e-01
# Evaluation 300, objective function = 1.95846e+00, constraint residuals = 6.119e-01
# Evaluation 301, objective function = 1.96470e+00, constraint residuals = 4.490e-01
# Evaluation 302, objective function = 1.95892e+00, constraint residuals = 5.843e-01
# Evaluation 303, objective function = 1.96539e+00, constraint residuals = 6.908e-01
# Evaluation 304, objective function = 1.96022e+00, constraint residuals = 4.168e-01
# Evaluation 305, objective function = 1.97763e+00, constraint residuals = 5.974e-01
# Evaluation 306, objective function = 2.03981e+00, constraint residuals = 7.815e-01
# Evaluation 307, objective function = 1.96698e+00, constraint residuals = 5.787e-01
# Evaluation 308, objective function = 1.99949e+00, constraint residuals = 1.962e-01
# Evaluation 309, objective function = 1.95846e+00, constraint residuals = 9.303e-01
# Evaluation 310, objective function = 1.94126e+00, constraint residuals = 4.533e-01
# Evaluation 311, objective function = 1.96105e+00, constraint residuals = 8.009e-01
# Evaluation 312, objective function = 2.01339e+00, constraint residuals = 9.599e-02
# Evaluation 313, objective function = 1.97029e+00, constraint residuals = 1.871e-01
# Evaluation 314, objective function = 1.95102e+00, constraint residuals = 6.649e-01
# Evaluation 315, objective function = 1.99558e+00, constraint residuals = 1.970e-01
# Evaluation 316, objective function = 2.02382e+00, constraint residuals = 6.752e-01
# Evaluation 317, objective function = 1.97518e+00, constraint residuals = 2.827e-01
# Evaluation 318, objective function = 2.04501e+00, constraint residuals = 6.995e-01
# Evaluation 319, objective function = 1.97546e+00, constraint residuals = 2.620e-01
# Evaluation 320, objective function = 2.05549e+00, constraint residuals = 1.263e+00
# Evaluation 321, objective function = 1.97479e+00, constraint residuals = 3.089e-01
# Evaluation 322, objective function = 2.01297e+00, constraint residuals = 4.828e-01
# Evaluation 323, objective function = 1.97397e+00, constraint residuals = 1.867e-01
# Evaluation 324, objective function = 2.01151e+00, constraint residuals = 4.092e-01
# Evaluation 325, objective function = 1.97563e+00, constraint residuals = 4.074e-01
# Evaluation 326, objective function = 2.01246e+00, constraint residuals = 7.764e-01
# Evaluation 327, objective function = 1.97499e+00, constraint residuals = 2.987e-01
# Evaluation 328, objective function = 2.01034e+00, constraint residuals = 7.959e-01
# Evaluation 329, objective function = 1.97161e+00, constraint residuals = 1.501e-01
# Evaluation 330, objective function = 2.01019e+00, constraint residuals = 4.958e-01
# Evaluation 331, objective function = 1.97564e+00, constraint residuals = 4.097e-01
# Evaluation 332, objective function = 2.01041e+00, constraint residuals = 7.748e-01
# Evaluation 333, objective function = 1.97504e+00, constraint residuals = 2.993e-01
# Evaluation 334, objective function = 2.05095e+00, constraint residuals = 6.210e-01
# Evaluation 335, objective function = 1.92763e+00, constraint residuals = 7.436e-01
# Evaluation 336, objective function = 1.99319e+00, constraint residuals = 8.256e-01
# Evaluation 337, objective function = 1.97586e+00, constraint residuals = 1.719e-01
# Evaluation 338, objective function = 1.89588e+00, constraint residuals = 1.230e+00
# Evaluation 339, objective function = 1.96614e+00, constraint residuals = 6.285e-01
# Evaluation 340, objective function = 2.03448e+00, constraint residuals = 1.229e+00
# Evaluation 341, objective function = 1.95174e+00, constraint residuals = 4.613e-01
# Evaluation 342, objective function = 2.06585e+00, constraint residuals = 1.308e+00
# Evaluation 343, objective function = 1.97588e+00, constraint residuals = 1.392e-01
# Evaluation 344, objective function = 2.05183e+00, constraint residuals = 1.266e+00
# Evaluation 345, objective function = 1.96768e+00, constraint residuals = 3.067e-01
# Evaluation 346, objective function = 2.00581e+00, constraint residuals = 1.615e+00
# Evaluation 347, objective function = 1.95500e+00, constraint residuals = 3.595e-01
# Evaluation 348, objective function = 2.05289e+00, constraint residuals = 9.908e-01
# Evaluation 349, objective function = 2.04274e+00, constraint residuals = 1.195e+00
# Evaluation 350, objective function = 1.98330e+00, constraint residuals = 1.605e-01
# Evaluation 351, objective function = 2.05826e+00, constraint residuals = 4.994e-01
# Evaluation 352, objective function = 1.98470e+00, constraint residuals = 1.243e-01
# Evaluation 353, objective function = 2.05711e+00, constraint residuals = 6.144e-01
# Evaluation 354, objective function = 1.97990e+00, constraint residuals = 1.840e-01
# Evaluation 355, objective function = 2.06033e+00, constraint residuals = 9.487e-01
# Evaluation 356, objective function = 1.97262e+00, constraint residuals = 2.745e-01
# Evaluation 357, objective function = 2.12049e+00, constraint residuals = 1.302e+00
# Evaluation 358, objective function = 1.97137e+00, constraint residuals = 1.735e-01
# Evaluation 359, objective function = 2.02163e+00, constraint residuals = 1.535e+00
# Evaluation 360, objective function = 1.98607e+00, constraint residuals = 1.151e-01
# Evaluation 361, objective function = 1.98036e+00, constraint residuals = 1.084e+00
# Evaluation 362, objective function = 1.98610e+00, constraint residuals = 1.048e-01
# Evaluation 363, objective function = 1.96708e+00, constraint residuals = 3.081e-01
# Evaluation 364, objective function = 2.07617e+00, constraint residuals = 6.983e-01
# Evaluation 365, objective function = 2.00529e+00, constraint residuals = 4.364e-01
# Evaluation 366, objective function = 1.95858e+00, constraint residuals = 3.655e-01
# Evaluation 367, objective function = 2.07052e+00, constraint residuals = 6.191e-01
# Evaluation 368, objective function = 1.95830e+00, constraint residuals = 4.094e-01
# Evaluation 369, objective function = 1.99725e+00, constraint residuals = 1.006e+00
# Evaluation 370, objective function = 2.05400e+00, constraint residuals = 7.312e-01
# Evaluation 371, objective function = 1.93418e+00, constraint residuals = 4.328e-01
# Evaluation 372, objective function = 2.02545e+00, constraint residuals = 2.650e-01
# Evaluation 373, objective function = 1.93670e+00, constraint residuals = 8.012e-01
# Evaluation 374, objective function = 1.92918e+00, constraint residuals = 7.222e-01
# Evaluation 375, objective function = 1.98025e+00, constraint residuals = 4.913e-01
# Evaluation 376, objective function = 1.98011e+00, constraint residuals = 1.249e-01
# Evaluation 377, objective function = 2.00992e+00, constraint residuals = 7.197e-01
# Evaluation 378, objective function = 1.96974e+00, constraint residuals = 1.523e-01
# Evaluation 379, objective function = 1.98745e+00, constraint residuals = 7.918e-01
# Evaluation 380, objective function = 1.95660e+00, constraint residuals = 3.414e-01
# Evaluation 381, objective function = 1.98743e+00, constraint residuals = 9.501e-01
# Evaluation 382, objective function = 1.96033e+00, constraint residuals = 3.683e-01
# Evaluation 383, objective function = 1.99693e+00, constraint residuals = 3.143e-01
# Evaluation 384, objective function = 1.98272e+00, constraint residuals = 2.205e-01
# Evaluation 385, objective function = 1.97442e+00, constraint residuals = 5.520e-01
# Evaluation 386, objective function = 1.98050e+00, constraint residuals = 4.443e-01
# Evaluation 387, objective function = 1.97903e+00, constraint residuals = 7.145e-01
# Evaluation 388, objective function = 2.00726e+00, constraint residuals = 7.466e-01
# Evaluation 389, objective function = 1.97647e+00, constraint residuals = 2.791e-01
# Evaluation 390, objective function = 1.99075e+00, constraint residuals = 6.721e-01
# Evaluation 391, objective function = 1.97977e+00, constraint residuals = 2.004e-01
# Evaluation 392, objective function = 1.99570e+00, constraint residuals = 8.033e-01
# Evaluation 393, objective function = 1.97318e+00, constraint residuals = 4.314e-01
# Evaluation 394, objective function = 2.00066e+00, constraint residuals = 7.056e-01
# Evaluation 395, objective function = 1.97560e+00, constraint residuals = 1.138e-01
# Evaluation 396, objective function = 1.99067e+00, constraint residuals = 6.107e-01
# Evaluation 397, objective function = 1.97288e+00, constraint residuals = 5.208e-01
# Evaluation 398, objective function = 1.98764e+00, constraint residuals = 5.044e-01
# Evaluation 399, objective function = 1.97368e+00, constraint residuals = 4.897e-01
# Evaluation 400, objective function = 1.99243e+00, constraint residuals = 8.375e-01
# Evaluation 401, objective function = 1.97972e+00, constraint residuals = 1.977e-01
# Evaluation 402, objective function = 1.99936e+00, constraint residuals = 5.290e-01
# Evaluation 403, objective function = 1.97336e+00, constraint residuals = 4.154e-01
# Evaluation 404, objective function = 1.99616e+00, constraint residuals = 5.735e-01
# Evaluation 405, objective function = 1.97643e+00, constraint residuals = 2.142e-01
# Evaluation 406, objective function = 1.99298e+00, constraint residuals = 1.028e+00
# Evaluation 407, objective function = 2.00271e+00, constraint residuals = 3.407e-01
# Evaluation 408, objective function = 1.99341e+00, constraint residuals = 4.615e-01
# Evaluation 409, objective function = 1.97735e+00, constraint residuals = 1.719e-01
# Evaluation 410, objective function = 1.99446e+00, constraint residuals = 7.524e-01
# Evaluation 411, objective function = 1.96398e+00, constraint residuals = 6.063e-01
# Evaluation 412, objective function = 1.98660e+00, constraint residuals = 2.789e-01
# Evaluation 413, objective function = 1.97795e+00, constraint residuals = 1.315e-01
# Evaluation 414, objective function = 1.99716e+00, constraint residuals = 7.892e-01
# Evaluation 415, objective function = 1.97557e+00, constraint residuals = 2.969e-01
# Evaluation 416, objective function = 1.98901e+00, constraint residuals = 9.912e-01
# Evaluation 417, objective function = 1.97497e+00, constraint residuals = 1.114e-01
# Evaluation 418, objective function = 1.99083e+00, constraint residuals = 8.349e-01
# Evaluation 419, objective function = 1.97909e+00, constraint residuals = 1.234e-01
# Evaluation 420, objective function = 1.99581e+00, constraint residuals = 7.430e-01
# Evaluation 421, objective function = 1.97971e+00, constraint residuals = 2.086e-01
# Evaluation 422, objective function = 1.99056e+00, constraint residuals = 6.790e-01
# Evaluation 423, objective function = 1.97961e+00, constraint residuals = 1.976e-01
# Evaluation 424, objective function = 1.99857e+00, constraint residuals = 1.082e+00
# Evaluation 425, objective function = 2.00647e+00, constraint residuals = 5.455e-01
# Evaluation 426, objective function = 1.89014e+00, constraint residuals = 1.061e+00
# Evaluation 427, objective function = 2.02438e+00, constraint residuals = 4.874e-01
# Evaluation 428, objective function = 1.91293e+00, constraint residuals = 1.546e+00
# Evaluation 429, objective function = 1.96800e+00, constraint residuals = 6.094e-01
# Evaluation 430, objective function = 1.98000e+00, constraint residuals = 2.046e-01
# Evaluation 431, objective function = 1.95258e+00, constraint residuals = 4.200e-01
# Evaluation 432, objective function = 1.97998e+00, constraint residuals = 2.055e-01
# Evaluation 433, objective function = 1.96847e+00, constraint residuals = 4.774e-01
# Evaluation 434, objective function = 1.98001e+00, constraint residuals = 2.038e-01
# Evaluation 435, objective function = 1.97887e+00, constraint residuals = 4.816e-01
# Evaluation 436, objective function = 1.97982e+00, constraint residuals = 1.916e-01
# Evaluation 437, objective function = 1.96542e+00, constraint residuals = 4.384e-01
# Evaluation 438, objective function = 1.98565e+00, constraint residuals = 1.119e-01
# Evaluation 439, objective function = 1.95995e+00, constraint residuals = 8.107e-01
# Evaluation 440, objective function = 1.99322e+00, constraint residuals = 4.390e-01
# Evaluation 441, objective function = 1.97516e+00, constraint residuals = 1.815e-01
# Evaluation 442, objective function = 1.99722e+00, constraint residuals = 6.661e-01
# Evaluation 443, objective function = 1.97519e+00, constraint residuals = 1.777e-01
# Evaluation 444, objective function = 1.99899e+00, constraint residuals = 3.622e-01
# Evaluation 445, objective function = 1.95918e+00, constraint residuals = 4.770e-01
# Evaluation 446, objective function = 2.01134e+00, constraint residuals = 4.665e-01
# Evaluation 447, objective function = 2.01146e+00, constraint residuals = 1.890e-01
# Evaluation 448, objective function = 2.00842e+00, constraint residuals = 5.251e-01
# Evaluation 449, objective function = 1.92545e+00, constraint residuals = 1.093e+00
# Evaluation 450, objective function = 1.99245e+00, constraint residuals = 1.025e+00
# Evaluation 451, objective function = 1.96850e+00, constraint residuals = 2.250e-01
# Evaluation 452, objective function = 1.99146e+00, constraint residuals = 6.072e-01
# Evaluation 453, objective function = 1.96768e+00, constraint residuals = 2.374e-01
# Evaluation 454, objective function = 1.99637e+00, constraint residuals = 5.723e-01
# Evaluation 455, objective function = 1.98249e+00, constraint residuals = 1.871e-01
# Evaluation 456, objective function = 1.98784e+00, constraint residuals = 4.544e-01
# Evaluation 457, objective function = 1.88856e+00, constraint residuals = 9.768e-01
# Evaluation 458, objective function = 1.98538e+00, constraint residuals = 4.384e-01
# Evaluation 459, objective function = 1.96306e+00, constraint residuals = 2.084e-01
# Evaluation 460, objective function = 1.98627e+00, constraint residuals = 8.271e-01
# Evaluation 461, objective function = 1.95464e+00, constraint residuals = 3.040e-01
# Evaluation 462, objective function = 1.98549e+00, constraint residuals = 6.980e-01
# Evaluation 463, objective function = 1.95390e+00, constraint residuals = 3.369e-01
# Evaluation 464, objective function = 1.96682e+00, constraint residuals = 6.568e-01
# Evaluation 465, objective function = 1.96590e+00, constraint residuals = 2.702e-01
# Evaluation 466, objective function = 2.03075e+00, constraint residuals = 5.808e-01
# Evaluation 467, objective function = 1.98068e+00, constraint residuals = 4.113e-01
# Evaluation 468, objective function = 1.92267e+00, constraint residuals = 5.240e-01
# Evaluation 469, objective function = 1.96360e+00, constraint residuals = 3.438e-01
# Evaluation 470, objective function = 2.06131e+00, constraint residuals = 8.635e-01
# Evaluation 471, objective function = 1.96108e+00, constraint residuals = 4.601e-01
# Evaluation 472, objective function = 2.00533e+00, constraint residuals = 2.755e-01
# Evaluation 473, objective function = 1.92727e+00, constraint residuals = 3.297e-01
# Evaluation 474, objective function = 2.03677e+00, constraint residuals = 3.996e-01
# Evaluation 475, objective function = 1.90204e+00, constraint residuals = 4.290e-01
# Evaluation 476, objective function = 2.02465e+00, constraint residuals = 5.606e-01
# Evaluation 477, objective function = 1.91363e+00, constraint residuals = 3.776e-01
# Evaluation 478, objective function = 2.04914e+00, constraint residuals = 1.195e+00
# Evaluation 479, objective function = 1.97232e+00, constraint residuals = 2.061e-01
# Evaluation 480, objective function = 1.98367e+00, constraint residuals = 4.018e-01
# Evaluation 481, objective function = 1.97092e+00, constraint residuals = 1.921e-01
# Evaluation 482, objective function = 1.98378e+00, constraint residuals = 5.034e-01
# Evaluation 483, objective function = 1.96515e+00, constraint residuals = 3.130e-01
# Evaluation 484, objective function = 1.98555e+00, constraint residuals = 7.034e-01
# Evaluation 485, objective function = 1.98552e+00, constraint residuals = 6.043e-01
# Evaluation 486, objective function = 1.90432e+00, constraint residuals = 5.183e-01
# Evaluation 487, objective function = 1.98472e+00, constraint residuals = 4.929e-01
# Evaluation 488, objective function = 1.98555e+00, constraint residuals = 7.404e-01
# Evaluation 489, objective function = 1.97040e+00, constraint residuals = 2.942e-01
# Evaluation 490, objective function = 1.98566e+00, constraint residuals = 4.274e-01
# Evaluation 491, objective function = 1.98411e+00, constraint residuals = 4.419e-01
# Evaluation 492, objective function = 1.97277e+00, constraint residuals = 1.881e-01
# Evaluation 493, objective function = 1.98441e+00, constraint residuals = 4.676e-01
# Evaluation 494, objective function = 1.92374e+00, constraint residuals = 4.137e-01
# Evaluation 495, objective function = 1.98531e+00, constraint residuals = 3.977e-01
# Evaluation 496, objective function = 1.96912e+00, constraint residuals = 2.376e-01
# Evaluation 497, objective function = 1.98830e+00, constraint residuals = 2.519e-01
# Evaluation 498, objective function = 1.96985e+00, constraint residuals = 3.626e-01
# Evaluation 499, objective function = 1.98478e+00, constraint residuals = 6.624e-01
# Evaluation 500, objective function = 1.97172e+00, constraint residuals = 3.094e-01
# Evaluation 501, objective function = 1.98476e+00, constraint residuals = 4.990e-01
# Evaluation 502, objective function = 1.91880e+00, constraint residuals = 8.595e-01
# Evaluation 503, objective function = 1.98282e+00, constraint residuals = 2.818e-01
# Evaluation 504, objective function = 1.93036e+00, constraint residuals = 5.698e-01
# Evaluation 505, objective function = 1.98364e+00, constraint residuals = 3.514e-01
# Evaluation 506, objective function = 1.99666e+00, constraint residuals = 3.154e-01
# Evaluation 507, objective function = 2.00991e+00, constraint residuals = 5.913e-01
# Evaluation 508, objective function = 1.97698e+00, constraint residuals = 3.040e-01
# Evaluation 509, objective function = 1.98334e+00, constraint residuals = 5.942e-01
# Evaluation 510, objective function = 1.93748e+00, constraint residuals = 6.294e-01
# Evaluation 511, objective function = 1.99064e+00, constraint residuals = 4.464e-01
# Evaluation 512, objective function = 1.97763e+00, constraint residuals = 3.003e-01
# Evaluation 513, objective function = 1.98571e+00, constraint residuals = 4.233e-01
# Evaluation 514, objective function = 1.87613e+00, constraint residuals = 7.568e-01
# Evaluation 515, objective function = 1.98449e+00, constraint residuals = 3.098e-01
# Evaluation 516, objective function = 1.97781e+00, constraint residuals = 2.930e-01
# Evaluation 517, objective function = 1.98929e+00, constraint residuals = 1.982e-01
# Evaluation 518, objective function = 1.97526e+00, constraint residuals = 2.666e-01
# Evaluation 519, objective function = 1.98245e+00, constraint residuals = 2.152e-01
# Evaluation 520, objective function = 1.97746e+00, constraint residuals = 2.215e-01
# Evaluation 521, objective function = 1.98379e+00, constraint residuals = 2.832e-01
# Evaluation 522, objective function = 1.95960e+00, constraint residuals = 3.201e-01
# Evaluation 523, objective function = 1.98571e+00, constraint residuals = 6.735e-01
# Evaluation 524, objective function = 1.94373e+00, constraint residuals = 5.326e-01
# Evaluation 525, objective function = 1.98553e+00, constraint residuals = 4.431e-01
# Evaluation 526, objective function = 1.97865e+00, constraint residuals = 1.865e-01
# Evaluation 527, objective function = 1.98929e+00, constraint residuals = 2.109e-01
# Evaluation 528, objective function = 1.97885e+00, constraint residuals = 1.833e-01
# Evaluation 529, objective function = 1.98274e+00, constraint residuals = 4.556e-01
# Evaluation 530, objective function = 1.98805e+00, constraint residuals = 2.257e-01
# Evaluation 531, objective function = 1.97854e+00, constraint residuals = 1.755e-01
# Evaluation 532, objective function = 1.98412e+00, constraint residuals = 4.753e-01
# Evaluation 533, objective function = 1.97743e+00, constraint residuals = 3.840e-01
# Evaluation 534, objective function = 1.98705e+00, constraint residuals = 3.587e-01
# Evaluation 535, objective function = 1.97727e+00, constraint residuals = 1.977e-01
# Evaluation 536, objective function = 1.98830e+00, constraint residuals = 2.951e-01
# Evaluation 537, objective function = 1.97932e+00, constraint residuals = 1.921e-01
# Evaluation 538, objective function = 1.98971e+00, constraint residuals = 2.552e-01
# Evaluation 539, objective function = 1.97794e+00, constraint residuals = 1.776e-01
# Evaluation 540, objective function = 1.98747e+00, constraint residuals = 2.535e-01
# Evaluation 541, objective function = 1.98199e+00, constraint residuals = 2.956e-01
# Evaluation 542, objective function = 1.98731e+00, constraint residuals = 3.948e-01
# Evaluation 543, objective function = 1.97881e+00, constraint residuals = 1.798e-01
# Evaluation 544, objective function = 2.00878e+00, constraint residuals = 8.387e-01
# Evaluation 545, objective function = 1.97856e+00, constraint residuals = 1.042e-01
# Evaluation 546, objective function = 1.96745e+00, constraint residuals = 6.132e-01
# Evaluation 547, objective function = 1.97656e+00, constraint residuals = 1.064e-01
# Evaluation 548, objective function = 1.96101e+00, constraint residuals = 7.695e-01
# Evaluation 549, objective function = 1.98496e+00, constraint residuals = 8.222e-02
# Evaluation 550, objective function = 1.97890e+00, constraint residuals = 1.208e-01
# Evaluation 551, objective function = 1.94993e+00, constraint residuals = 4.192e-01
# Evaluation 552, objective function = 1.98083e+00, constraint residuals = 1.022e+00
# ...
# Evaluation 2865, objective function = 1.99783e+00, constraint residuals = 1.556e-04
# Evaluation 2866, objective function = 1.99775e+00, constraint residuals = 5.317e-03
# Evaluation 2867, objective function = 1.99793e+00, constraint residuals = 6.902e-05
# Evaluation 2868, objective function = 1.99745e+00, constraint residuals = 6.827e-03
# Evaluation 2869, objective function = 1.99704e+00, constraint residuals = 5.980e-03
# Evaluation 2870, objective function = 1.99784e+00, constraint residuals = 2.987e-04
# Evaluation 2871, objective function = 1.99658e+00, constraint residuals = 1.025e-02
# Evaluation 2872, objective function = 1.99786e+00, constraint residuals = 3.232e-04
# Evaluation 2873, objective function = 1.99693e+00, constraint residuals = 8.882e-03
# Evaluation 2874, objective function = 1.99621e+00, constraint residuals = 1.069e-02
# Evaluation 2875, objective function = 1.99690e+00, constraint residuals = 7.729e-03
# Evaluation 2876, objective function = 1.99786e+00, constraint residuals = 2.851e-04
# Evaluation 2877, objective function = 1.99693e+00, constraint residuals = 8.878e-03
# Evaluation 2878, objective function = 1.99686e+00, constraint residuals = 1.326e-02
# Evaluation 2879, objective function = 1.99623e+00, constraint residuals = 1.339e-02
# Evaluation 2880, objective function = 1.99719e+00, constraint residuals = 7.242e-03
# Evaluation 2881, objective function = 1.99783e+00, constraint residuals = 1.143e-04
# Evaluation 2882, objective function = 1.99735e+00, constraint residuals = 9.239e-03
# Evaluation 2883, objective function = 1.99692e+00, constraint residuals = 9.715e-03
# Evaluation 2884, objective function = 1.99690e+00, constraint residuals = 7.035e-03
# Evaluation 2885, objective function = 1.99732e+00, constraint residuals = 5.479e-03
# Evaluation 2886, objective function = 1.99725e+00, constraint residuals = 6.837e-03
# Evaluation 2887, objective function = 1.99783e+00, constraint residuals = 1.258e-04
# Evaluation 2888, objective function = 1.99653e+00, constraint residuals = 1.111e-02
# Evaluation 2889, objective function = 1.99784e+00, constraint residuals = 1.332e-04
# Evaluation 2890, objective function = 1.99764e+00, constraint residuals = 8.432e-03
# Evaluation 2891, objective function = 1.99671e+00, constraint residuals = 1.110e-02
# Evaluation 2892, objective function = 1.99783e+00, constraint residuals = 1.174e-04
# Evaluation 2893, objective function = 1.99779e+00, constraint residuals = 6.053e-03
# Evaluation 2894, objective function = 1.99787e+00, constraint residuals = 7.537e-05
# Evaluation 2895, objective function = 1.99687e+00, constraint residuals = 1.215e-02
# Evaluation 2896, objective function = 1.99785e+00, constraint residuals = 1.030e-02
# Evaluation 2897, objective function = 1.99652e+00, constraint residuals = 9.955e-03
# Evaluation 2898, objective function = 1.99786e+00, constraint residuals = 3.259e-05
# Evaluation 2899, objective function = 1.99662e+00, constraint residuals = 1.215e-02
# Evaluation 2900, objective function = 1.99783e+00, constraint residuals = 1.155e-04
# Evaluation 2901, objective function = 1.99734e+00, constraint residuals = 8.379e-03
# Evaluation 2902, objective function = 1.99692e+00, constraint residuals = 8.042e-03
# Evaluation 2903, objective function = 1.99783e+00, constraint residuals = 1.095e-04
# Evaluation 2904, objective function = 1.99616e+00, constraint residuals = 1.243e-02
# Evaluation 2905, objective function = 1.99668e+00, constraint residuals = 8.379e-03
# Evaluation 2906, objective function = 1.99783e+00, constraint residuals = 1.489e-04
# Evaluation 2907, objective function = 1.99734e+00, constraint residuals = 6.290e-03
# Evaluation 2908, objective function = 1.99782e+00, constraint residuals = 4.574e-03
# Evaluation 2909, objective function = 1.99681e+00, constraint residuals = 1.046e-02
# Evaluation 2910, objective function = 1.99738e+00, constraint residuals = 1.039e-02
# Evaluation 2911, objective function = 1.99627e+00, constraint residuals = 1.385e-02
# Evaluation 2912, objective function = 1.99639e+00, constraint residuals = 1.018e-02
# Evaluation 2913, objective function = 1.99783e+00, constraint residuals = 1.392e-04
# Evaluation 2914, objective function = 1.99610e+00, constraint residuals = 1.355e-02
# Evaluation 2915, objective function = 1.99786e+00, constraint residuals = 9.034e-05
# Evaluation 2916, objective function = 1.99634e+00, constraint residuals = 9.659e-03
# Evaluation 2917, objective function = 1.99783e+00, constraint residuals = 1.202e-04
# Evaluation 2918, objective function = 1.99710e+00, constraint residuals = 1.062e-02
# Evaluation 2919, objective function = 1.99738e+00, constraint residuals = 5.383e-03
# Evaluation 2920, objective function = 1.99698e+00, constraint residuals = 8.570e-03
# Evaluation 2921, objective function = 1.99653e+00, constraint residuals = 1.172e-02
# Evaluation 2922, objective function = 1.99744e+00, constraint residuals = 7.980e-03
# Evaluation 2923, objective function = 1.99662e+00, constraint residuals = 1.001e-02
# Evaluation 2924, objective function = 1.99783e+00, constraint residuals = 1.249e-04
# Evaluation 2925, objective function = 1.99708e+00, constraint residuals = 6.140e-03
# Evaluation 2926, objective function = 1.99734e+00, constraint residuals = 6.013e-03
# Evaluation 2927, objective function = 1.99837e+00, constraint residuals = 3.403e-03
# Evaluation 2928, objective function = 1.99785e+00, constraint residuals = 1.567e-04
# Evaluation 2929, objective function = 1.99773e+00, constraint residuals = 1.182e-02
# Evaluation 2930, objective function = 1.99790e+00, constraint residuals = 1.322e-04
# Evaluation 2931, objective function = 1.99789e+00, constraint residuals = 4.571e-05
# Evaluation 2932, objective function = 1.99787e+00, constraint residuals = 5.307e-03
# Evaluation 2933, objective function = 1.99786e+00, constraint residuals = 2.776e-05
# Evaluation 2934, objective function = 1.99749e+00, constraint residuals = 4.607e-03
# Evaluation 2935, objective function = 1.99787e+00, constraint residuals = 6.616e-03
# Evaluation 2936, objective function = 1.99786e+00, constraint residuals = 4.349e-05
# Evaluation 2937, objective function = 1.99777e+00, constraint residuals = 4.836e-03
# Evaluation 2938, objective function = 1.99793e+00, constraint residuals = 1.178e-03
# Evaluation 2939, objective function = 1.99791e+00, constraint residuals = 8.577e-04
# Evaluation 2940, objective function = 1.99791e+00, constraint residuals = 1.046e-03
# Evaluation 2941, objective function = 1.99811e+00, constraint residuals = 5.295e-05
# Evaluation 2942, objective function = 1.99780e+00, constraint residuals = 4.010e-03
# Evaluation 2943, objective function = 1.99786e+00, constraint residuals = 1.320e-03
# Evaluation 2944, objective function = 1.99786e+00, constraint residuals = 2.435e-03
# Evaluation 2945, objective function = 1.99784e+00, constraint residuals = 1.907e-03
# Evaluation 2946, objective function = 1.99785e+00, constraint residuals = 9.368e-05
# Evaluation 2947, objective function = 1.99794e+00, constraint residuals = 8.607e-04
# Evaluation 2948, objective function = 1.99789e+00, constraint residuals = 8.252e-04
# Evaluation 2949, objective function = 1.99792e+00, constraint residuals = 6.360e-04
# Evaluation 2950, objective function = 1.99788e+00, constraint residuals = 1.078e-03
# Evaluation 2951, objective function = 1.99789e+00, constraint residuals = 1.247e-03
# Evaluation 2952, objective function = 1.99791e+00, constraint residuals = 5.973e-04
# Evaluation 2953, objective function = 1.99791e+00, constraint residuals = 5.917e-04
# Evaluation 2954, objective function = 1.99791e+00, constraint residuals = 1.597e-03
# Evaluation 2955, objective function = 1.99786e+00, constraint residuals = 1.157e-05
# Evaluation 2956, objective function = 1.99792e+00, constraint residuals = 5.455e-04
# Evaluation 2957, objective function = 1.99786e+00, constraint residuals = 1.371e-05
# Evaluation 2958, objective function = 1.99788e+00, constraint residuals = 1.078e-03
# Evaluation 2959, objective function = 1.99794e+00, constraint residuals = 9.653e-04
# Evaluation 2960, objective function = 1.99786e+00, constraint residuals = 1.512e-05
# Evaluation 2961, objective function = 1.99792e+00, constraint residuals = 7.907e-04
# Evaluation 2962, objective function = 1.99790e+00, constraint residuals = 1.461e-03
# Evaluation 2963, objective function = 1.99791e+00, constraint residuals = 1.239e-03
# Evaluation 2964, objective function = 1.99790e+00, constraint residuals = 1.231e-03
# Evaluation 2965, objective function = 1.99793e+00, constraint residuals = 7.476e-04
# Evaluation 2966, objective function = 1.99787e+00, constraint residuals = 4.665e-05
# Evaluation 2967, objective function = 1.99792e+00, constraint residuals = 8.458e-04
# Evaluation 2968, objective function = 1.99786e+00, constraint residuals = 2.364e-05
# Evaluation 2969, objective function = 1.99788e+00, constraint residuals = 1.056e-03
# Evaluation 2970, objective function = 1.99789e+00, constraint residuals = 1.201e-03
# Evaluation 2971, objective function = 1.99786e+00, constraint residuals = 2.357e-05
# Evaluation 2972, objective function = 1.99788e+00, constraint residuals = 6.740e-04
# Evaluation 2973, objective function = 1.99786e+00, constraint residuals = 2.086e-05
# Evaluation 2974, objective function = 1.99788e+00, constraint residuals = 7.549e-04
# Evaluation 2975, objective function = 1.99788e+00, constraint residuals = 1.292e-03
# Evaluation 2976, objective function = 1.99793e+00, constraint residuals = 1.363e-03
# Evaluation 2977, objective function = 1.99786e+00, constraint residuals = 2.117e-05
# Evaluation 2978, objective function = 1.99788e+00, constraint residuals = 1.376e-03
# Evaluation 2979, objective function = 1.99793e+00, constraint residuals = 9.553e-04
# Evaluation 2980, objective function = 1.99786e+00, constraint residuals = 1.356e-05
# Evaluation 2981, objective function = 1.99794e+00, constraint residuals = 7.058e-04
# Evaluation 2982, objective function = 1.99789e+00, constraint residuals = 1.433e-03
# Evaluation 2983, objective function = 1.99786e+00, constraint residuals = 8.323e-06
# Evaluation 2984, objective function = 1.99789e+00, constraint residuals = 1.844e-03
# Evaluation 2985, objective function = 1.99787e+00, constraint residuals = 1.860e-03
# Evaluation 2986, objective function = 1.99785e+00, constraint residuals = 3.544e-05
# Evaluation 2987, objective function = 1.99789e+00, constraint residuals = 7.283e-04
# Evaluation 2988, objective function = 1.99786e+00, constraint residuals = 1.106e-03
# Evaluation 2989, objective function = 1.99784e+00, constraint residuals = 9.697e-05
# Evaluation 2990, objective function = 1.99766e+00, constraint residuals = 3.788e-03
# Evaluation 2991, objective function = 1.99764e+00, constraint residuals = 4.267e-03
# Evaluation 2992, objective function = 1.99784e+00, constraint residuals = 8.667e-05
# Evaluation 2993, objective function = 1.99774e+00, constraint residuals = 1.972e-03
# Evaluation 2994, objective function = 1.99760e+00, constraint residuals = 2.913e-03
# Evaluation 2995, objective function = 1.99784e+00, constraint residuals = 4.617e-03
# Evaluation 2996, objective function = 1.99784e+00, constraint residuals = 8.163e-05
# process.io.plot_solutions - ERROR - nlopt running baseline_jan_2017 has failed
# Traceback (most recent call last):
#   File "/home/jon/code/process/process/io/plot_solutions.py", line 276, in run_regression_input
#     single_run.run()
#   File "/home/jon/code/process/process/main.py", line 374, in run
#     self.run_scan(self.solver)
#   File "/home/jon/code/process/process/main.py", line 473, in run_scan
#     self.scan = Scan(self.models, solver)
#   File "/home/jon/code/process/process/scan.py", line 22, in __init__
#     self.run_scan()
#   File "/home/jon/code/process/process/scan.py", line 36, in run_scan
#     ifail = self.doopt()
#   File "/home/jon/code/process/process/scan.py", line 56, in doopt
#     ifail = self.optimiser.run()
#   File "/home/jon/code/process/process/optimiser.py", line 59, in run
#     ifail = self.solver.solve()
#   File "/home/jon/code/process/process/solver.py", line 379, in solve
#     raise RuntimeError("nlopt's MAXEVAL evaluations limit reached")
# RuntimeError: nlopt's MAXEVAL evaluations limit reached
# process.io.plot_solutions - WARNING - baseline_jan_2017 using nlopt has failed.
# process.io.plot_solutions - ERROR - ifail missing from MFILE: exception likely thrown.
# Traceback (most recent call last):
#   File "/home/jon/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3652, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas/_libs/index.pyx", line 147, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 176, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7080, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7088, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'ifail'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/jon/code/process/process/io/plot_solutions.py", line 307, in run_and_print
#     results_df["ifail"]
#   File "/home/jon/.local/lib/python3.10/site-packages/pandas/core/frame.py", line 3760, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/home/jon/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3654, in get_loc
#     raise KeyError(key) from err
# KeyError: 'ifail'
# Evaluation 2997, objective function = 1.99784e+00, constraint residuals = 8.193e-03
# Evaluation 2998, objective function = 1.99785e+00, constraint residuals = 1.082e-05
# Evaluation 2999, objective function = 1.99787e+00, constraint residuals = 1.019e-05
# Evaluation 3000, objective function = 1.99784e+00, constraint residuals = 3.748e-03
# nlopt running baseline_jan_2017 has failed
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ifail'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 results_df = ps.run_and_print("baseline_jan_2017", "nlopt", rerun=True)
#
# File ~/code/process/process/io/plot_solutions.py:307, in run_and_print(scenario, solver, rerun)
#     305 # (use absence of minmax as a sign of not working)
#     306 try:
# --> 307     results_df["ifail"]
#     308 except KeyError:
#     309     logger.exception("ifail missing from MFILE: exception likely thrown.")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:3760, in DataFrame.__getitem__(self, key)
#    3758 if self.columns.nlevels > 1:
#    3759     return self._getitem_multilevel(key)
# -> 3760 indexer = self.columns.get_loc(key)
#    3761 if is_integer(indexer):
#    3762     indexer = [indexer]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'ifail'
