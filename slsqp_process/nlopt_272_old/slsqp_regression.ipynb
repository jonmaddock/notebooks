# %% [markdown]
# # nlopt's SLSQP on regression tests

# %%
# Reload Process each time (keep editable install up-to-date)
# %load_ext autoreload
# %autoreload 2

from process.io import plot_solutions as ps
from pathlib import Path

# %% [markdown]
# ## Regression run
#
# Run a full regression run, using the built nlopt's SLSQP.

# %%
results_df = ps.compare_solvers_regression_tests(["legacy_vmcon", "nlopt"], rerun_tests=False)
# Out:
# The IN.DAT file does not contain any obsolete variables.
#
#  **************************************************************************************************************
#  ************************************************** PROCESS ***************************************************
#  ************************************** Power Reactor Optimisation Code ***************************************
#  **************************************************************************************************************
#
#    Program :
#    Version : 2.4.0   Release Date :: 2022-05-18
#    Tag No. : v2.4.0-913-g759a689f1 code contains untracked changes
#     Branch : 1813-implement-nlopt-s-slsqp-solver
#  Warning in routine OCMMNT :
#   Git log : Overwrite regression references for |Merge branch |1829-numba-performance-warnings-in-sctfcoil| into |develop||
# This is longer than 110 columns.
# ...

# %%
ps.compare_solvers_regression_test("starfire", ["legacy_vmcon", "nlopt"], rerun_tests=False)
# Out:
#               tag  scenario solver    objf_name itvar001_name itvar002_name
# 1  starfire_nlopt  starfire  nlopt  fusion gain            te          beta  \
#
#   itvar003_name itvar004_name itvar005_name itvar006_name  ...     xcm017
# 1          dene         fdene         hfact         tfcth  ... -60.844847  \
#
#       xcm018      xcm019     xcm020 xcm021     xcm022 xcm023 xcm024
# 1 -91.446841  521.329501 -31.572503    0.0 -60.699311    0.0    0.0  \
#
#        xcm025 xcm026
# 1  155.400578    0.0
#
# [1 rows x 57 columns]

# %% [markdown]
# Whilst this was run with nlopt 2.7.2, it was an old version of Process, which didn't include objf_name. Process had to be rebuilt and starfire run again to get the above plot. The rest of the data will be missing objf_name unless re-run.
