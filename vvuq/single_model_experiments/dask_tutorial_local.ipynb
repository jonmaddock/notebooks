# %%
from dask_jobqueue import SLURMCluster
from dask.distributed import Client, progress, LocalCluster
import time

# %%
# Init cluster (describes a single node)
# cluster = SLURMCluster(
#     cores=1,
#     processes=1,  # check docs
#     memory="4GB",
#     account="UKAEA-AP001-CPU",
#     walltime="00:10:00",
#     queue="cclake",
# )
# cluster.scale(4)  # 16 workers (i.e. nodes?)
# print(cluster.job_script())

# Create Dask client associated with cluster
# Connect scheduler to workers
# client = Client(cluster)

# Code from now on submitted to batch queue


def slow_increment(x):
    time.sleep(1)
    return x + 1

# %%
client = Client()
client
# Out:
# /home/jon/code/notebooks/vvuq/.venv/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 46199 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:46879' processes=4 threads=8, memory=31.08 GiB>

# %%
futures = client.map(slow_increment, range(100))
progress(futures)
# Out:
# VBox()
